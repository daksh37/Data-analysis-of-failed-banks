# %%
import seaborn as sbs
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\navgu\Desktop\linkedin\banks.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3484 entries, 0 to 3483
# Data columns (total 12 columns):
# Financial Institution Number    2883 non-null float64
# Institution Name                3484 non-null object
# Institution Type                3484 non-null object
# Charter Type                    3484 non-null object
# Headquarters                    3484 non-null object
# Failure Date                    3484 non-null object
# Insurance Fund                  3484 non-null object
# Certificate Number              2999 non-null float64
# Transaction Type                3484 non-null object
# Total Deposits                  3484 non-null int64
# Total Assets                    3333 non-null float64
# Estimated Loss (2015)           2509 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 326.7+ KB
#    Financial Institution Number             Institution Name Institution Type  \
# ...

# %%
sbs.countplot(df['Charter Type'])

# %%
corr=df.corr()
fig,ax=plt.subplots(figsize=(8,8))
sbs.heatmap(corr,vmax=0.8,square=True)

# %%
df['liquidity']=df['Total Deposits']/df['Total Assets'] *100

# %%
df.plot.scatter(x='Total Deposits',y='Total Assets')

# %%
df.plot.scatter(x='Estimated Loss (2015)',y='liquidity')

# %%
sbs.stripplot(x='Charter Type',y='Estimated Loss (2015)',data=df,jitter=True)

# %%
sbs.stripplot(x = 'Charter Type', y = 'Total Assets', data = df, jitter = True);

# %%
sbs.stripplot(x = 'Charter Type', y = 'Total Deposits', data = df, jitter = True);

# %%
sbs.stripplot(x = 'Institution Type', y = 'Estimated Loss (2015)', data = df, jitter = True);

# %%
sbs.stripplot(x = 'Insurance Fund', y = 'Estimated Loss (2015)', data = df, jitter = True);

# %%
sbs.stripplot(x = 'Insurance Fund', y = 'Total Assets', data = df, jitter = True);

# %%
sbs.countplot( y = 'Institution Type', data = df);

# %%
sbs.stripplot(x = 'Transaction Type', y = 'Estimated Loss (2015)', data = df, jitter = True);

# %%
hq = df['Headquarters'].value_counts()

# %%
hq[:20].plot(kind='bar')

# %%
sbs.distplot(df['liquidity'],hist = True, bins = 50)
